# %% [markdown]
# # ALMACENAMIENTO DE DATOS DE SQL A ARCHIVOS CSV

# %%
import sqlite3 as sql
connection = sql.connect('ds_salaries.sqlite')

# 2. Creación de un objeto cursor
cursor = connection.cursor()

# 3. Se crea una consulta de prueba
q = '''
SELECT *
FROM ds_salaries
'''

# 4. Se ejecuta el query
cursor.execute(q)

# 5. Se obtienen los resultados de la consulta
results = cursor.fetchall()

for r in results:
    print(r)
# Out:
# (None, 'work_year', 'experience_level', 'employment_type', 'job_title', 'salary', 'salary_currency', 'salary_in_usd', 'employee_residence', 'remote_ratio', 'company_location', 'company_size')
# (0, '2020', 'MI', 'FT', 'Data Scientist', '70000', 'EUR', '79833', 'DE', '0', 'DE', 'L')
# (1, '2020', 'SE', 'FT', 'Machine Learning Scientist', '260000', 'USD', '260000', 'JP', '0', 'JP', 'S')
# (2, '2020', 'SE', 'FT', 'Big Data Engineer', '85000', 'GBP', '109024', 'GB', '50', 'GB', 'M')
# (3, '2020', 'MI', 'FT', 'Product Data Analyst', '20000', 'USD', '20000', 'HN', '0', 'HN', 'S')
# (4, '2020', 'SE', 'FT', 'Machine Learning Engineer', '150000', 'USD', '150000', 'US', '50', 'US', 'L')
# (5, '2020', 'EN', 'FT', 'Data Analyst', '72000', 'USD', '72000', 'US', '100', 'US', 'L')
# (6, '2020', 'SE', 'FT', 'Lead Data Scientist', '190000', 'USD', '190000', 'US', '100', 'US', 'S')
# (7, '2020', 'MI', 'FT', 'Data Scientist', '11000000', 'HUF', '35735', 'HU', '50', 'HU', 'L')
# ...

# %%
# Crea la consulta
q = '''
SELECT CAST(c2 AS INT) as yir, c9 as ctry, c5 as job_title, CAST(c8 AS FLOAT) as salary
FROM ds_salaries;
'''
# Ejecuta la consulta
cursor.execute(q)
# Obtiene resultados
results = cursor.fetchall()
# Imprime
for r in results:
    print(r)
# Out:
# (0, 'employee_residence', 'job_title', 0.0)
# (2020, 'DE', 'Data Scientist', 79833.0)
# (2020, 'JP', 'Machine Learning Scientist', 260000.0)
# (2020, 'GB', 'Big Data Engineer', 109024.0)
# (2020, 'HN', 'Product Data Analyst', 20000.0)
# (2020, 'US', 'Machine Learning Engineer', 150000.0)
# (2020, 'US', 'Data Analyst', 72000.0)
# (2020, 'US', 'Lead Data Scientist', 190000.0)
# (2020, 'HU', 'Data Scientist', 35735.0)
# (2020, 'US', 'Business Data Analyst', 135000.0)
# (2020, 'NZ', 'Lead Data Engineer', 125000.0)
# (2020, 'FR', 'Data Scientist', 51321.0)
# (2020, 'IN', 'Data Scientist', 40481.0)
# (2020, 'FR', 'Data Scientist', 39916.0)
# (2020, 'US', 'Lead Data Analyst', 87000.0)
# (2020, 'US', 'Data Analyst', 85000.0)
# (2020, 'PK', 'Data Analyst', 8000.0)
# (2020, 'JP', 'Data Engineer', 41689.0)
# (2020, 'PL', 'Big Data Engineer', 114047.0)
# (2020, 'IN', 'Data Science Consultant', 5707.0)
# (2020, 'PT', 'Lead Data Engineer', 56000.0)
# ...

# %%
import pandas as pd
df = pd.DataFrame(results)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 608 entries, 0 to 607
# Data columns (total 4 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   year       608 non-null    int64
#  1   country    608 non-null    object
#  2   job_title  608 non-null    object
#  3   salary     608 non-null    float64
# dtypes: float64(1), int64(1), object(2)
# memory usage: 19.1+ KB

# %%
# Agregar los nombres de columnas
col_titles = ['year','country','job_title','salary']
df.columns = col_titles

# %% [markdown]
# A csv

# %%
df.to_csv('ds_salaries.csv')

# %%
cursor.close()
connection.close()
