# %% [markdown]
# # A 4.1 Integración de datos

# %%
import pandas as pd
import matplotlib.pyplot as plt
import re

from fontTools.subset import prune_hints

# %%
t01 = pd.read_excel("table01.xlsx")
t01.info()
t02 = pd.read_csv("table02.csv")
t02.info()
t03 = pd.read_csv("table03.csv")
t03.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50 entries, 0 to 49
# Data columns (total 5 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   CustomerID   50 non-null     int64
#  1   Email        50 non-null     object
#  2   OrderDate    50 non-null     datetime64[ns]
#  3   OrderAmount  50 non-null     float64
#  4   ShipAddress  50 non-null     object
# dtypes: datetime64[ns](1), float64(1), int64(1), object(2)
# memory usage: 2.1+ KB
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 34 entries, 0 to 33
# Data columns (total 5 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   CustID         34 non-null     int64
#  1   Customer_Name  34 non-null     object
#  2   Purchase_Date  34 non-null     object
#  3   Total_Spent    34 non-null     float64
#  4   Location       33 non-null     object
# dtypes: float64(1), int64(1), object(3)
# memory usage: 1.5+ KB
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 41 entries, 0 to 40
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   MemberID      41 non-null     int64
#  1   Member_Email  40 non-null     object
#  2   JoinDate      40 non-null     object
#  3   Points        40 non-null     float64
#  4   Address       40 non-null     object
# dtypes: float64(1), int64(1), object(3)
# memory usage: 1.7+ KB

# %% [markdown]
# ### Estandarizar nombres de columnas: elegir una convención de nomenclatura coherente. (2 pts)

# %%
# Se cambiaron los nombres de las columnas para tener un nombre unico en las tres, para hacer las siguientes operaciones mas facil
t01 = t01.rename(columns={'CustomerID':'cID'})
t02 = t02.rename(columns={'CustID':'cID'})
t03 = t03.rename(columns={'MemberID':'cID'})

# %%
t01 = t01.rename(columns={'Email':'cEmail'})
t03 = t03.rename(columns={'Member_Email':'cEmail'})

# %%
t01 = t01.rename(columns={'ShipAddress':'cAddress'})
t03 = t03.rename(columns={'Address':'cAddress'})

# %%
t01.info()
t02.info()
t03.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50 entries, 0 to 49
# Data columns (total 5 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   cID          50 non-null     int64
#  1   cEmail       50 non-null     object
#  2   OrderDate    50 non-null     datetime64[ns]
#  3   OrderAmount  50 non-null     float64
#  4   cAddress     50 non-null     object
# dtypes: datetime64[ns](1), float64(1), int64(1), object(2)
# memory usage: 2.1+ KB
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 34 entries, 0 to 33
# Data columns (total 5 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   cID            34 non-null     int64
#  1   Customer_Name  34 non-null     object
#  2   Purchase_Date  34 non-null     object
#  3   Total_Spent    34 non-null     float64
#  4   Location       33 non-null     object
# dtypes: float64(1), int64(1), object(3)
# memory usage: 1.5+ KB
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 41 entries, 0 to 40
# Data columns (total 5 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   cID       41 non-null     int64
#  1   cEmail    40 non-null     object
#  2   JoinDate  40 non-null     object
#  3   Points    40 non-null     float64
#  4   cAddress  40 non-null     object
# dtypes: float64(1), int64(1), object(3)
# memory usage: 1.7+ KB

# %% [markdown]
# ### Estandarizar formatos de datos: convertir todas las fechas a un formato uniforme.

# %%
t01['OrderDate'] = pd.to_datetime(t01['OrderDate'])
t02['Purchase_Date'] = pd.to_datetime(t02['Purchase_Date'])
t03['JoinDate'] = pd.to_datetime(t03['JoinDate'])

# %%
t01
# Out:
#      cID                     cEmail  OrderDate  OrderAmount  \
# 0   1001         john.doe@email.com 2024-10-26       125.50
# 1   1002       jane.smith@email.com 2024-10-27        50.00
# 2   1003      peter.jones@email.com 2024-10-28       200.75
# 3   1004       mary.brown@email.com 2024-10-28        75.25
# 4   1005        david.lee@email.com 2024-10-29        90.00
# 5   1006      sarah.white@email.com 2024-10-30       150.00
# 6   1007     robert.green@email.com 2024-10-31        60.50
# 7   1008      linda.black@email.com 2024-11-01       110.25
# 8   1009     michael.blue@email.com 2024-11-02        85.00
# 9   1010    jennifer.gray@email.com 2024-11-03       175.75
# 10  1011  christopher.red@email.com 2024-11-04        95.00
# 11  1012    amanda.yellow@email.com 2024-11-05       135.25
# 12  1013    daniel.orange@email.com 2024-11-06        70.00
# 13  1014   melissa.purple@email.com 2024-11-07       120.50
# 14  1015       kevin.pink@email.com 2024-11-08       100.00
# 15  1016     ashley.brown@email.com 2024-11-09       160.75
# 16  1017       ryan.white@email.com 2024-11-10        80.00
# 17  1018     nicole.green@email.com 2024-11-11       140.25
# 18  1019      jason.black@email.com 2024-11-12       115.00
# 19  1020   stephanie.blue@email.com 2024-11-13        90.00
# 20  1021        eric.gray@email.com 2024-11-14       180.75
# 21  1022     michelle.red@email.com 2024-11-15       100.00
# 22  1023    justin.yellow@email.com 2024-11-16       145.25
# 23  1024    amanda.orange@email.com 2024-11-17        75.00
# 24  1025     brian.purple@email.com 2024-11-18       125.50
# 25  1026      lauren.pink@email.com 2024-11-19       105.00
# 26  1027       adam.brown@email.com 2024-11-20       165.75
# 27  1028  catherine.white@email.com 2024-11-21        85.00
# 28  1029    matthew.green@email.com 2024-11-22       145.25
# 29  1030     rachel.black@email.com 2024-11-23       120.00
# 30  1031      nathan.blue@email.com 2024-11-24        95.00
# 31  1032      olivia.gray@email.com 2024-11-25       185.75
# 32  1033       samuel.red@email.com 2024-11-26       105.00
# 33  1034     paige.yellow@email.com 2024-11-27       150.25
# 34  1035    andrew.orange@email.com 2024-11-28        80.00
# 35  1036  victoria.purple@email.com 2024-11-29       130.50
# 36  1037     patrick.pink@email.com 2024-11-30       110.00
# 37  1038    jessica.brown@email.com 2024-12-01       170.75
# 38  1039    matthew.white@email.com 2024-12-02        90.00
# 39  1040    brandon.green@email.com 2024-12-03       150.25
# 40  1041   samantha.black@email.com 2024-12-04       125.00
# 41  1042        cody.blue@email.com 2024-12-05       100.00
# 42  1043       emily.gray@email.com 2024-12-06       190.75
# 43  1044      zachary.red@email.com 2024-12-07       110.00
# 44  1045    hannah.yellow@email.com 2024-12-08       155.25
# 45  1046     jacob.orange@email.com 2024-12-09        85.00
# 46  1047    kaylee.purple@email.com 2024-12-10       135.50
# 47  1048      austin.pink@email.com 2024-12-11       115.00
# 48  1049    natalie.brown@email.com 2024-12-12       175.75
# 49  1050      ethan.white@email.com 2024-12-13        95.00
#
#                            cAddress
# 0                       123 Main St
# 1                       456 Oak Ave
# 2                       789 Pine Ln
# 3                        321 Elm Rd
# 4                  654 Pinecrest Dr
# 5                     999 Willow Dr
# 6                     246 Maple Ave
# 7                      135 Cedar Ln
# 8                      864 Birch Rd
# 9                     579 Spruce St
# 10                   258 Walnut Ave
# 11                    159 Cherry Ln
# 12                   876 Hickory Rd
# 13                  581 Sycamore St
# 14                  263 Redwood Ave
# 15                   168 Oakwood Ln
# 16                 794 Pinehurst Dr
# 17                279 Maplewood Ave
# 18                148 Cedarcrest Ln
# 19                 873 Birchwood Rd
# 20                584 Sprucelawn St
# 21              267 Walnutcrest Ave
# 22                164 Cherrywood Ln
# 23              881 Hickorycrest Rd
# 24              586 Sycamorelawn St
# 25             268 Redwoodcrest Ave
# 26              173 Oakwoodcrest Ln
# 27            799 Pinehurstcrest Dr
# 28           284 Maplewoodcrest Ave
# 29           153 Cedarcrestcrest Ln
# 30            878 Birchwoodcrest Rd
# 31           589 Sprucelawncrest St
# 32         272 Walnutcrestcrest Ave
# 33           169 Cherrywoodcrest Ln
# 34         886 Hickorycrestcrest Rd
# 35         591 Sycamorelawncrest St
# 36        274 Redwoodcrestcrest Ave
# 37         179 Oakwoodcrestcrest Ln
# 38       804 Pinehurstcrestcrest Dr
# 39      289 Maplewoodcrestcrest Ave
# 40      158 Cedarcrestcrestcrest Ln
# 41       883 Birchwoodcrestcrest Rd
# 42      594 Sprucelawncrestcrest St
# 43    277 Walnutcrestcrestcrest Ave
# 44      174 Cherrywoodcrestcrest Ln
# 45    891 Hickorycrestcrestcrest Rd
# 46    596 Sycamorelawncrestcrest St
# 47   279 Redwoodcrestcrestcrest Ave
# 48    184 Oakwoodcrestcrestcrest Ln
# 49  809 Pinehurstcrestcrestcrest Dr

# %%
t02 = t02.sort_values(by="cID", ascending=True)
t02
# Out:
#      cID    Customer_Name Purchase_Date  Total_Spent Location
# 0   1001         John Doe    2024-10-26       130.00  Store A
# 3   1002       Jane Smith    2024-10-27        49.99  Store C
# 1   1003      Peter Jones    2024-10-28       195.50  Store B
# 2   1005        David Lee    2024-10-29        90.00  Store A
# 4   1006      Sarah White    2024-10-30       155.00  Store D
# 5   1007     Robert Green    2024-10-31        62.00  Store B
# 6   1008      Linda Black    2024-11-01       112.50  Store A
# 7   1009     Michael Blue    2024-11-02        87.00  Store C
# 8   1010    Jennifer Gray    2024-11-03       178.00  Store D
# 9   1011  Christopher Red    2024-11-04        97.00  Store B
# 10  1012    Amanda Yellow    2024-11-05       137.50  Store A
# 11  1013    Daniel Orange    2024-11-06        72.00  Store C
# 12  1014   Melissa Purple    2024-11-07       122.50  Store D
# 13  1015       Kevin Pink    2024-11-08       102.00  Store B
# 14  1016     Ashley Brown    2024-11-09       163.00  Store A
# 15  1017       Ryan White    2024-11-10        82.00  Store C
# 16  1018     Nicole Green    2024-11-11       142.50  Store D
# 17  1019      Jason Black    2024-11-12       117.00  Store B
# 18  1020   Stephanie Blue    2024-11-13        92.00  Store A
# 19  1021        Eric Gray    2024-11-14       183.00  Store C
# 20  1022     Michelle Red    2024-11-15       102.00  Store D
# 21  1023    Justin Yellow    2024-11-16       147.50  Store B
# 22  1024    Amanda Orange    2024-11-17        77.00  Store A
# 23  1025     Brian Purple    2024-11-18       127.50  Store C
# 24  1026      Lauren Pink    2024-11-19       107.00  Store D
# 25  1027       Adam Brown    2024-11-20       168.00  Store B
# 26  1028  Catherine White    2024-11-21        87.00  Store A
# 27  1029    Matthew Green    2024-11-22       147.50  Store C
# 28  1030     Rachel Black    2024-11-23       122.00  Store D
# 29  1031      Nathan Blue    2024-11-24        97.00  Store B
# 30  1032      Olivia Gray    2024-11-25       188.00  Store A
# 31  1033       Samuel Red    2024-11-26       107.00  Store C
# 32  1034     Paige Yellow    2024-11-27       152.50  Store D
# 33  1035    Andrew Orange    2024-11-28        82.00      NaN

# %%
t03
# Out:
#      cID                     cEmail   JoinDate  Points  \
# 0   1001         john.doe@email.com 2023-05-15  1500.0
# 1   1002       jane.smith@email.com 2023-08-01   800.0
# 2   1003      peter.jones@email.com 2023-11-20  2200.0
# 3   1006      sarah.white@email.com 2024-01-10   300.0
# 4   1007     robert.green@email.com 2024-02-15   450.0
# 5   1008      linda.black@email.com 2024-03-20   600.0
# 6   1009     michael.blue@email.com 2024-04-25   750.0
# 7   1010    jennifer.gray@email.com 2024-05-30   900.0
# 8   1011  christopher.red@email.com 2024-06-04  1050.0
# 9   1012    amanda.yellow@email.com 2024-07-09  1200.0
# 10  1013    daniel.orange@email.com 2024-08-14  1350.0
# 11  1014   melissa.purple@email.com 2024-09-19  1500.0
# 12  1015       kevin.pink@email.com 2024-10-24  1650.0
# 13  1016     ashley.brown@email.com 2024-10-28  1800.0
# 14  1017       ryan.white@email.com 2024-11-02  1950.0
# 15  1018     nicole.green@email.com 2024-11-07  2100.0
# 16  1019      jason.black@email.com 2024-11-12  2250.0
# 17  1020   stephanie.blue@email.com 2024-11-17  2400.0
# 18  1021        eric.gray@email.com 2024-11-22  2550.0
# 19  1022     michelle.red@email.com 2024-11-27  2700.0
# 20  1023    justin.yellow@email.com 2024-12-02  2850.0
# 21  1024    amanda.orange@email.com 2024-12-07  3000.0
# 22  1025     brian.purple@email.com 2024-12-12  3150.0
# 23  1026      lauren.pink@email.com 2024-12-17  3300.0
# 24  1027       adam.brown@email.com 2024-12-22  3450.0
# 25  1028  catherine.white@email.com 2024-12-27  3600.0
# 26  1029    matthew.green@email.com 2025-01-01  3750.0
# 27  1030     rachel.black@email.com 2025-01-06  3900.0
# 28  1031      nathan.blue@email.com 2025-01-11  4050.0
# 29  1032      olivia.gray@email.com 2025-01-16  4200.0
# 30  1033       samuel.red@email.com 2025-01-21  4350.0
# 31  1034     paige.yellow@email.com 2025-01-26  4500.0
# 32  1035    andrew.orange@email.com 2025-01-31  4650.0
# 33  1036  victoria.purple@email.com 2025-02-05  4800.0
# 34  1037     patrick.pink@email.com 2025-02-10  4950.0
# 35  1038    jessica.brown@email.com 2025-02-15  5100.0
# 36  1039    matthew.white@email.com 2025-02-20  5250.0
# 37  1040    brandon.green@email.com 2025-02-25  5400.0
# 38  1041   samantha.black@email.com 2025-03-02  5550.0
# 39  1042        cody.blue@email.com 2025-03-07  5700.0
# 40  1043                        NaN        NaT     NaN
#
#                           cAddress
# 0                  123 Main Street
# 1                   456 Oak Avenue
# 2                    789 Pine Lane
# 3                 999 Willow Drive
# 4                 246 Maple Avenue
# 5                   135 Cedar Lane
# 6                   864 Birch Road
# 7                579 Spruce Street
# 8                258 Walnut Avenue
# 9                  159 Cherry Lane
# 10                876 Hickory Road
# 11             581 Sycamore Street
# 12              263 Redwood Avenue
# 13                168 Oakwood Lane
# 14             794 Pinehurst Drive
# 15            279 Maplewood Avenue
# 16             148 Cedarcrest Lane
# 17              873 Birchwood Road
# 18           584 Sprucelawn Street
# 19          267 Walnutcrest Avenue
# 20             164 Cherrywood Lane
# 21           881 Hickorycrest Road
# 22         586 Sycamorelawn Street
# 23         268 Redwoodcrest Avenue
# 24           173 Oakwoodcrest Lane
# 25        799 Pinehurstcrest Drive
# 26       284 Maplewoodcrest Avenue
# 27        153 Cedarcrestcrest Lane
# 28         878 Birchwoodcrest Road
# 29      589 Sprucelawncrest Street
# 30     272 Walnutcrestcrest Avenue
# 31        169 Cherrywoodcrest Lane
# 32      886 Hickorycrestcrest Road
# 33    591 Sycamorelawncrest Street
# 34    274 Redwoodcrestcrest Avenue
# 35      179 Oakwoodcrestcrest Lane
# 36   804 Pinehurstcrestcrest Drive
# 37  289 Maplewoodcrestcrest Avenue
# 38   158 Cedarcrestcrestcrest Lane
# 39    883 Birchwoodcrestcrest Road
# 40                             NaN

# %% [markdown]
# ### Gestionar valores faltantes: determinar cómo dirigirse a los clientes presentes en algunas tablas, pero no en otras. (2 pts)
#
# Tras analizar los datos, se puede determinar en la primera tabla, que pidieron una orden en internet por cierta cantidad, y ya se fue a recoger en físico a la tienda real, donde se terminó pagando *[Ejemplo, se ordena y paga en tienda]*. Ahora bien, algunos clientes no fueron a recoger su pedido, por lo cual no se completaría y, por lo tanto, aparecería en la segunda tabla. En cuanto a la tercera, existe la posibilidad donde el cliente no tiene una cuenta en el programa de fidelización.
#
# Se pueden crear tres columnas extras al hacer merge:
# 1. Comision *[Resta entre lo pagado y el total de internet]*
# 2. Orden completada *[True, False]* *[Se encuentra, o no, en la segunda tabla]*
# 3. Miembro_VIP *[True, False]* *[Se encuentra, o no, en el programa de fidelización]*

# %% [markdown]
# ### Resolver discrepancias de direcciones: limpiar y estandarizar los datos de direcciones

# %%
abbr = {
    "Street": "St", "Avenue": "Ave", "Lane": "Ln", "Road": "Rd", "Drive": "Dr"
}

def limpio(addr):
    for long, short in abbr.items():
        addr = re.sub(rf'\b{long}\b', short, addr) # Reorganiza el string ya con las abreviaturas hechas
    return addr.strip()  # Elimina espacios en blanco


t01["cAddress"] = t01["cAddress"].astype(str).apply(limpio)
t03["cAddress"] = t03["cAddress"].astype(str).apply(limpio)

# %% [markdown]
# ### Resolver discrepancias de importe: determinar si las diferencias se deben a impuestos u otros factores.
#
# Las discrepancias en el importe se puede tomar como una cortesía, en caso de que sea negativo, y una pequeña comisión, pues las diferencias rondan entre 2 y 2.25, con algunos datos que se salen de esto, siendo de $5, un centavo, y ninguna diferencia.

# %% [markdown]
# # Merge

# %%
import pandas as pd

# Merge de t01 y t03 utilizando cID, cEmail y cAddress
merged = pd.merge(t01, t03, on=["cID", "cEmail", "cAddress"], how="outer")

# Se establece si son clientes del programa de fidelidad (True si tienen Join_Date)
merged["Joined_VIP"] = merged["JoinDate"].notna()

# Merge con t02 utilizando cID
merged = pd.merge(merged, t02, on="cID", how="outer")

# Se crea la columnda de orden completada (True si existen datos tanto Order_Date como Purchase_Date)
merged["Order_Completed"] = merged["OrderDate"].notna() & merged["Purchase_Date"].notna()

# Converte los valores NaN en puntos, order y total a 0
merged["Points"] = merged["Points"].fillna(0)
merged["OrderAmount"] = merged["OrderAmount"].fillna(0)
merged["Total_Spent"] = merged["Total_Spent"].fillna(0)

# Calcula la comisión como Total_Spent - Order_Amount, si es menor a 0, se mantiene en 0
merged["Commision"] = (merged["Total_Spent"] - merged["OrderAmount"]).round(2).clip(lower=0)


MergedData = merged[[
    "cID", "Customer_Name", "cEmail", "cAddress", "JoinDate", "Joined_VIP", "Points", "OrderDate", "Purchase_Date", "Order_Completed", "OrderAmount", "Total_Spent", "Commision", "Location"
]]

# Guardar el resultado en un archivo CSV
MergedData.to_csv("MergedData.csv")

# %% [markdown]
# # Análisis descriptivo basado en el uso de gráficas

# %%
propo = MergedData["Joined_VIP"].value_counts()
propolab = 'Si','No'
plt.pie(propo, labels=propolab, autopct='%1.1f%%')
plt.title("¿El cliente se encuentra en el programa de fidelidad?")
plt.show()

# %% [markdown]
# 1 de cada 5 personas no se encuentra en el programa de fidelidad. Esta cifra es buena, pero puede ser mejor, ya que beneficia tanto al cliente como a la compañía

# %%
puntos_no0 = [p for p in MergedData["Points"] if p > 0]

plt.hist(puntos_no0, bins=10, color="royalblue", edgecolor="black", alpha=0.7)
plt.xlabel("Puntos")
plt.ylabel("Frecuencia")
plt.title("Distribución de Puntos entre Clientes")
plt.grid(axis="y", linestyle="--", alpha=0.7)
plt.show()

# %% [markdown]
# La distribución de los puntos es extrañamente estable. La mayoría de las personas tienen más de 2500 puntos. Dependiendo de cómo se canjeen los puntos, quisa sea buena opción reducir la cantidad ganada para que no afecte tanto a la compañía

# %%
ordenCompletada = MergedData["Order_Completed"].value_counts()

ordenCompletada.plot(kind="bar", color=["green", "red"])
plt.xticks(ticks=[0, 1], labels=["Completadas", "No Completadas"], rotation=0)
plt.ylabel("Cantidad de ordenes")
plt.title("Ordenes Completadas vs No Completadas")
plt.grid(axis="y", linestyle="--")

# %% [markdown]
# Al menos un tercio de las ordenes no han sido completadas, esto representa la falta de ingreso de la compañía. Se les debe de enviar un e-mail de recordatorio para que terminen el proceso.

# %%
MergedData['year'] = MergedData['JoinDate'].dt.year
tot_anio = MergedData.groupby('year').size()
#tot_anio
plt.plot(tot_anio.index, tot_anio, label='Total de Delitos', color='blue', marker='o')
plt.title('Total de Inscritos por Año')
plt.xlabel('Año')
plt.ylabel('Total Inscritos')
plt.grid(True)
plt.xticks([2023, 2024, 2025])
plt.show()
# Out:
# C:\Users\santl\AppData\Local\Temp\ipykernel_12416\4279620042.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   MergedData['year'] = MergedData['JoinDate'].dt.year

# %% [markdown]
# 2023 y 2025 parecen bajos. El primer año se puede deber a que recién se empezaba el programa, por lo que las inscripciones fueron bajas. En el 2025 solo se han tomado en cuenta los primeros meses, por lo cual este punto puede subir a medida que avance el año.

# %%
loc = MergedData["Location"].dropna()
locs = loc.value_counts()
plt.pie(locs.values, labels=locs.index, autopct='%1.1f%%', startangle=90)
plt.title(f'Distribucion de Ordenes por Tienda')

plt.show()

# %% [markdown]
# Dentro de las ordenes completadas, se mantiene un balance entre el número por tienda. Esto indica que de momento no se tienen que tomar medidas.
